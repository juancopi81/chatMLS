# %% [markdown]
# <a href="https://colab.research.google.com/github/juancopi81/chatMLS/blob/main/Text_Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Creating the text database

# %% [markdown]
# ## Install required packages

# %%
# !pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 40.9 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.9.0-py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 33.3 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 10.0 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2023.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: tokenizers, xxhash, urllib3, multiprocess, responses, huggingface-hub, transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.9.0 huggingface-hub-0.12.0 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.26.0 urllib3-1.26.14 xxhash-3.2.0

# %% [markdown]
# ## Upload raw dataset from Hugging Face

# %%
from datasets import load_dataset
mls_dataset = load_dataset("juancopi81/mls", split="train")
mls_dataset
# Out:
# Downloading readme:   0%|          | 0.00/623 [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration juancopi81--mls-a645ad9f5aee714c
# Downloading and preparing dataset None/None to /root/.cache/huggingface/datasets/juancopi81___parquet/juancopi81--mls-a645ad9f5aee714c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.12M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/142 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/juancopi81___parquet/juancopi81--mls-a645ad9f5aee714c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
# Dataset({
#     features: ['CHANNEL_NAME', 'URL', 'TITLE', 'DESCRIPTION', 'TRANSCRIPTION', 'SEGMENTS'],
#     num_rows: 142
# })

# %% [markdown]
# ## Inspect dataset

# %%
mls_dataset[80]["TITLE"]
# Out:
# '6.11 Machine Learning development process | Error analysis --[ML | Andrew Ng]'

# %% [markdown]
# ## Remove unused columns

# %%
mls_dataset = mls_dataset.remove_columns(["SEGMENTS", "CHANNEL_NAME", "DESCRIPTION"])

# %% [markdown]
# ## Convert to pandas dataframe

# %%
mls_dataset.set_format("pandas")
df = mls_dataset[:]
df.head()
# Out:
#                                            URL  \
# 0  https://www.youtube.com/watch?v=y8JgiWcUnU8
# 1  https://www.youtube.com/watch?v=AISftYVyS50
# 2  https://www.youtube.com/watch?v=hHYcNPfbBXQ
# 3  https://www.youtube.com/watch?v=EZN_uM3J3kI
# 4  https://www.youtube.com/watch?v=l16C3PKiHKg
#
#                                                TITLE  \
# 0  1.1 Machine Learning Overview | Welcome to mac...
# 1  1.2 Machine Learning Overview |  What is machi...
# 2  1.3 Machine Learning Overview |  Applications ...
# 3  1.4 Machine Learning Overview | Supervised lea...
# 4  1.5 Machine Learning Overview | Supervised lea...
#
#                                        TRANSCRIPTION
# 0   Welcome to machine learning. What is machine ...
# 1   So, what is machine learning? In this video y...
# 2   In this class, you learn about the state of t...
# 3   Machine learning is creating tremendous econo...
# 4   So, supervised learning algorithms learn to p...

# %%
# See max and min number of words in transcripptions
out = df['TRANSCRIPTION'].str.split().str.len().agg(['min','max'])
out
# Out:
# min     394
# max    2646
# Name: TRANSCRIPTION, dtype: int64

# %%
# Check if duplicate rows
duplicateRows = df[df.duplicated(['URL', 'TITLE'])]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [URL, TITLE, TRANSCRIPTION]
# Index: []

# %% [markdown]
# ## Split transcription columns in chunks of num_of_words

# %%
import pandas as pd

def split_by_number_of_words(df, column_to_split, num_of_words):
    """
    Takes a dataframe and split rows in columns_to_split that are larger than
    num_of_words
    :param df:
    :columns_to_split:
    :param num_of_words:
    :return: New dataframe with selected_column has less or equal num_of_words
    """
    n = num_of_words
    columns_to_duplicate = df.columns.symmetric_difference([column_to_split]).to_list()
    final_cols = columns_to_duplicate + [column_to_split]
    new_df = df.set_index(columns_to_duplicate)[column_to_split].str.split().apply(
        lambda x: pd.Series([' '.join(x[i:i+n]) for i in range(0, len(x), n)])
        ).stack().reset_index()
    new_df = new_df.rename(columns={0: column_to_split})
    final_df = new_df.loc[:, final_cols]
    return final_df

# %%
# Split transcription column in chunks of 500 words - To tune this
new_df = split_by_number_of_words(df, "TRANSCRIPTION", 500)

# %%
df
# Out:
#                                              URL  \
# 0    https://www.youtube.com/watch?v=y8JgiWcUnU8
# 1    https://www.youtube.com/watch?v=AISftYVyS50
# 2    https://www.youtube.com/watch?v=hHYcNPfbBXQ
# 3    https://www.youtube.com/watch?v=EZN_uM3J3kI
# 4    https://www.youtube.com/watch?v=l16C3PKiHKg
# ..                                           ...
# 137  https://www.youtube.com/watch?v=4hlH4TXtNms
# 138  https://www.youtube.com/watch?v=tX7L_441Jlo
# 139  https://www.youtube.com/watch?v=3FkPgerAhXo
# 140  https://www.youtube.com/watch?v=pdeGAhJ5pbE
# 141  https://www.youtube.com/watch?v=GF1oHP5uDR8
#
#                                                  TITLE  \
# 0    1.1 Machine Learning Overview | Welcome to mac...
# 1    1.2 Machine Learning Overview |  What is machi...
# 2    1.3 Machine Learning Overview |  Applications ...
# 3    1.4 Machine Learning Overview | Supervised lea...
# 4    1.5 Machine Learning Overview | Supervised lea...
# ..                                                 ...
# 137  10.13 Continuous State Spaces|Algorithm refine...
# 138  10.14 Continuous State Spaces | Algorithm refi...
# 139  10.15 Continuous State Spaces | Algorithm refi...
# 140  10.16 Continuous State Spaces |The state of re...
# 141  10.17 Conclusion | Summary and Thank you --[Ma...
#
#                                          TRANSCRIPTION
# 0     Welcome to machine learning. What is machine ...
# 1     So, what is machine learning? In this video y...
# 2     In this class, you learn about the state of t...
# 3     Machine learning is creating tremendous econo...
# 4     So, supervised learning algorithms learn to p...
# ..                                                 ...
# 137   In the last video, we saw a neural network ar...
# 138   In the learning algorithm that we developed, ...
# 139   In this video, we'll look at two further refi...
# 140   Reinforcement learning is an exciting set of ...
# 141   Welcome to the final video of this machine le...
#
# [142 rows x 3 columns]

# %%
new_df
# Out:
#                                                  TITLE  \
# 0    1.1 Machine Learning Overview | Welcome to mac...
# 1    1.2 Machine Learning Overview |  What is machi...
# 2    1.2 Machine Learning Overview |  What is machi...
# 3    1.3 Machine Learning Overview |  Applications ...
# 4    1.3 Machine Learning Overview |  Applications ...
# ..                                                 ...
# 420  10.15 Continuous State Spaces | Algorithm refi...
# 421  10.15 Continuous State Spaces | Algorithm refi...
# 422  10.15 Continuous State Spaces | Algorithm refi...
# 423  10.16 Continuous State Spaces |The state of re...
# 424  10.17 Conclusion | Summary and Thank you --[Ma...
#
#                                              URL  \
# 0    https://www.youtube.com/watch?v=y8JgiWcUnU8
# 1    https://www.youtube.com/watch?v=AISftYVyS50
# 2    https://www.youtube.com/watch?v=AISftYVyS50
# 3    https://www.youtube.com/watch?v=hHYcNPfbBXQ
# 4    https://www.youtube.com/watch?v=hHYcNPfbBXQ
# ..                                           ...
# 420  https://www.youtube.com/watch?v=3FkPgerAhXo
# 421  https://www.youtube.com/watch?v=3FkPgerAhXo
# 422  https://www.youtube.com/watch?v=3FkPgerAhXo
# 423  https://www.youtube.com/watch?v=pdeGAhJ5pbE
# 424  https://www.youtube.com/watch?v=GF1oHP5uDR8
#
#                                          TRANSCRIPTION
# 0    Welcome to machine learning. What is machine l...
# 1    So, what is machine learning? In this video yo...
# 2    to spend a lot of time on in this specializati...
# 3    In this class, you learn about the state of th...
# 4    by McKinsey, AI and machine learning is estima...
# ..                                                 ...
# 420  so this inner term becomes 1 over 2 m prime su...
# 421  is used more common than bash gradient descent...
# 422  times W, in which case you're back to the orig...
# 423  Reinforcement learning is an exciting set of t...
# 424  Welcome to the final video of this machine lea...
#
# [425 rows x 3 columns]

# %%
out = new_df['TRANSCRIPTION'].str.split().str.len().agg(['min','max'])
out
# Out:
# min      1
# max    500
# Name: TRANSCRIPTION, dtype: int64

# %%
# Inspect rows with less than n number of words
rows = new_df[new_df["TRANSCRIPTION"].str.split().str.len() < 40]

# %%
rows
# Out:
#                                                  TITLE  \
# 7    1.4 Machine Learning Overview | Supervised lea...
# 14   1.7 Machine Learning Overview | Unsupervised l...
# 22   1.10 Machine Learning Overview | Linear regres...
# 83   3.3 Classification | Decision boundary  --[Mac...
# 108  4.1 Advanced Learning Algorithms | Welcome!  -...
# 121  4.4 Neural Networks Intuition | Example Recogn...
# 127  4.6 Neural Networks Model | More complex neura...
# 188  5.11 Additional Neural Network Concepts | Adva...
# 214  6.6 Bias and variance |Establishing a baseline...
# 219  6.7 Bias and variance | Learning curves --[Mac...
# 297  8.1 Unsupervised Learning, Recommenders, Reinf...
# 323  8.9 Anomaly Detection | Gaussian (normal) dist...
# 350  9.3 Collaborative Filtering | Collaborative fi...
# 363  9.7 Collaborative Filtering | Finding related ...
#
#                                              URL  \
# 7    https://www.youtube.com/watch?v=EZN_uM3J3kI
# 14   https://www.youtube.com/watch?v=u7Y_b04upmQ
# 22   https://www.youtube.com/watch?v=vrTHO5zRq6s
# 83   https://www.youtube.com/watch?v=QJdIpRcL_4U
# 108  https://www.youtube.com/watch?v=cuU8pCflXCo
# 121  https://www.youtube.com/watch?v=3RIUt73mj3Q
# 127  https://www.youtube.com/watch?v=4-2FOgsMOpk
# 188  https://www.youtube.com/watch?v=yo6aW-D7sCM
# 214  https://www.youtube.com/watch?v=8Rl_2WQbmlc
# 219  https://www.youtube.com/watch?v=m0QgVaFS6O4
# 297  https://www.youtube.com/watch?v=faTk41hUGec
# 323  https://www.youtube.com/watch?v=kAVXR1qGjwU
# 350  https://www.youtube.com/watch?v=lrNPMtBH75w
# 363  https://www.youtube.com/watch?v=uXMa7YwDVbE
#
#                                          TRANSCRIPTION
# 7    a number. But there's also a second major type...
# 14   to share with you something that I find really...
# 22                  you can construct a cost function.
# 83                                              video.
# 108  to start by taking a quick look at how the hum...
# 121  one or more layers of a neural network and the...
# 127  of the previous layer. Let's put this into an ...
# 188  video, let's take a look at some alternative l...
# 214  is doing, there's one other thing that I found...
# 219  I hope will now make a lot more sense to you. ...
# 297           algorithm called a clustering algorithm.
# 323  it to build a more sophisticated anomaly detec...
# 350  interact with an item. In the next video, let'...
# 363  lot of these limitations. Content based filter...

# %% [markdown]
# ## Convert to Hugging Face dataset

# %%
from datasets import Dataset

mls_ds = Dataset.from_pandas(new_df)
mls_ds
# Out:
# Dataset({
#     features: ['TITLE', 'URL', 'TRANSCRIPTION'],
#     num_rows: 425
# })

# %% [markdown]
# ## Get transcription length

# %%
mls_ds = mls_ds.map(
    lambda x: {"transcription_length": len(x["TRANSCRIPTION"].split())}
)
mls_ds
# Out:
#   0%|          | 0/425 [00:00<?, ?ex/s]
# Dataset({
#     features: ['TITLE', 'URL', 'TRANSCRIPTION', 'transcription_length'],
#     num_rows: 425
# })

# %% [markdown]
# ## Remove columns with less than 40 words

# %%
mls_ds = mls_ds.filter(
    lambda x: x["transcription_length"] > 40
)

mls_ds
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Dataset({
#     features: ['TITLE', 'URL', 'TRANSCRIPTION', 'transcription_length'],
#     num_rows: 410
# })

# %%
mls_ds[100]
# Out:
# {'TITLE': '3.10 Regularization to Reduce Overfitting | Regularized linear regression-- [ML | Andrew Ng]',
#  'URL': 'https://www.youtube.com/watch?v=yRSKygmsvSI',
#  'TRANSCRIPTION': "or w dot product x plus b. And it turns out that by the rules of calculus, the derivatives look like this is one over two m times the sum i equals one through m of w dot x plus b minus y times two xj plus the derivative of the regularization term, which is lambda over two m times two wj. Notice that the second term does not have the summation term from j equals one through n anymore. The twos cancel out here and here and also here and here. And so it simplifies to this expression over here. And finally, remember that wx plus b is f of x. And so you can rewrite it as this expression down here. So this is why this expression is used to compute the gradient in regularized linear regression. So you now know how to implement regularized linear regression. Using this, you will reduce overfitting when you have a lot of features and relatively small training set. And this should let you get linear regression to work much better on many problems. In the next video, we'll take this regularization idea and apply it to logistic regression to avoid overfitting for logistic regression as well. Let's take a look at that in the next video.",
#  'transcription_length': 215}

# %%
# Add title to transcription
def concatenate_text(examples):
    return {
        "text": examples["TITLE"]
        + ": "
        + examples["TRANSCRIPTION"]
    }

# %% [markdown]
# ## Concatenta title to transcription
#
# The title contains relevant information

# %%
mls_ds = mls_ds.map(concatenate_text)
mls_ds
# Out:
#   0%|          | 0/410 [00:00<?, ?ex/s]
# Dataset({
#     features: ['TITLE', 'URL', 'TRANSCRIPTION', 'transcription_length', 'text'],
#     num_rows: 410
# })

# %%
mls_ds[400]
# Out:
# {'TITLE': '10.13 Continuous State Spaces|Algorithm refinement Improved neural network architecture-ML Andrew Ng',
#  'URL': 'https://www.youtube.com/watch?v=4hlH4TXtNms',
#  'TRANSCRIPTION': "In the last video, we saw a neural network architecture that would input the state in action and attempt to output the Q function, Q of sA. It turns out that there's a change to neural network architecture that makes this algorithm much more efficient. So most implementations of DQN actually use this more efficient architecture that we'll see in this video. Let's take a look. This was the neural network architecture we saw previously where it would input 12 numbers and output Q of sA. Whenever we are in some state s, we would have to carry out inference in the neural network separately four times to compute these four values so as to pick the action A that gives us the largest Q value. This is inefficient because we have to carry out inference four times from every single state. Instead, it turns out to be more efficient to train a single neural network to output all four of these values simultaneously. This is what it looks like. Here's a modified neural network architecture where the input is eight numbers corresponding to the state of the lunar lander. It then goes through the neural network with 64 units in the first hidden layer, 64 units in the second hidden layer. Now the output unit has four output units. The job of the neural network is to have the four output units output Q of s nothing, Q of s left, Q of s main, and Q of s right. The job of the neural network is to compute simultaneously the Q value for all four possible actions for when we are in the state s. This turns out to be more efficient because given a state s, we can run inference just once and get all four of these values and then very quickly pick the action A that maximizes Q of sA. You notice also in Bellman's equations, there's a step in which we have to compute max over A prime, Q of s prime A prime, this is multiplied by gamma and then there was plus R of s up here. This neural network also makes it much more efficient to compute this because we're getting Q of s prime A prime for all actions A prime at the same time. So you then just pick the max to compute this value for the right hand side of Bellman's equations. This change to the neural network architecture makes the algorithm much more efficient and so we will be using this architecture in the practice lab. Next, there's one other idea that will help the algorithm a lot, which is something called an Epsilon greedy policy, which affects how you choose actions even while you're still learning. Let's take a look at the next video at what that means.",
#  'transcription_length': 472,
#  'text': "10.13 Continuous State Spaces|Algorithm refinement Improved neural network architecture-ML Andrew Ng: In the last video, we saw a neural network architecture that would input the state in action and attempt to output the Q function, Q of sA. It turns out that there's a change to neural network architecture that makes this algorithm much more efficient. So most implementations of DQN actually use this more efficient architecture that we'll see in this video. Let's take a look. This was the neural network architecture we saw previously where it would input 12 numbers and output Q of sA. Whenever we are in some state s, we would have to carry out inference in the neural network separately four times to compute these four values so as to pick the action A that gives us the largest Q value. This is inefficient because we have to carry out inference four times from every single state. Instead, it turns out to be more efficient to train a single neural network to output all four of these values simultaneously. This is what it looks like. Here's a modified neural network architecture where the input is eight numbers corresponding to the state of the lunar lander. It then goes through the neural network with 64 units in the first hidden layer, 64 units in the second hidden layer. Now the output unit has four output units. The job of the neural network is to have the four output units output Q of s nothing, Q of s left, Q of s main, and Q of s right. The job of the neural network is to compute simultaneously the Q value for all four possible actions for when we are in the state s. This turns out to be more efficient because given a state s, we can run inference just once and get all four of these values and then very quickly pick the action A that maximizes Q of sA. You notice also in Bellman's equations, there's a step in which we have to compute max over A prime, Q of s prime A prime, this is multiplied by gamma and then there was plus R of s up here. This neural network also makes it much more efficient to compute this because we're getting Q of s prime A prime for all actions A prime at the same time. So you then just pick the max to compute this value for the right hand side of Bellman's equations. This change to the neural network architecture makes the algorithm much more efficient and so we will be using this architecture in the practice lab. Next, there's one other idea that will help the algorithm a lot, which is something called an Epsilon greedy policy, which affects how you choose actions even while you're still learning. Let's take a look at the next video at what that means."}

# %%
len(mls_ds["text"])
# Out:
# 410

# %% [markdown]
# #2. Embedding the documents of the text database

# %%
# !pip install -qU openai #pinecone-client
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 KB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for openai (pyproject.toml) ... done

# %%
import openai

# get API key from top-right dropdown on OpenAI website
openai.api_key = "OPEN-AI-KEY"

# %% [markdown]
# # Test key

# %%
query = "who was the 12th person on the moon and when did they land?"

# now query text-davinci-003 WITHOUT context
res = openai.Completion.create(
    engine='text-davinci-003',
    prompt=query,
    temperature=0,
    max_tokens=400,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    stop=None
)

res['choices'][0]['text'].strip()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-27-a4c6f6fe922d> in <module>
#       2
#       3 # now query text-davinci-003 WITHOUT context
# ----> 4 res = openai.Completion.create(
#       5     engine='text-davinci-003',
#       6     prompt=query,
#
# /usr/local/lib/python3.8/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.8/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     225             request_timeout=request_timeout,
#     226         )
# --> 227         resp, got_stream = self._interpret_response(result, stream)
#     228         return resp, got_stream, self.api_key
#     229
#
# /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     618         else:
#     619             return (
# --> 620                 self._interpret_response_line(
#     621                     result.content.decode("utf-8"),
#     622                     result.status_code,
#
# /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     678         stream_error = stream and "error" in resp.data
#     679         if stream_error or not 200 <= rcode < 300:
# --> 680             raise self.handle_error_response(
#     681                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     682             )
#
# AuthenticationError: Incorrect API key provided: OPEN-AI-KEY. You can find your API key at https://platform.openai.com/account/api-keys.

# %%
# first let's make it simpler to get answers
def complete(prompt):
    # query text-davinci-003
    res = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        temperature=0,
        max_tokens=400,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    return res['choices'][0]['text'].strip()

# %%
query = (
    "Which training method should I use for sentence transformers when " +
    "I only have pairs of related sentences?"
)

complete(query)
# Out:
# 'If you only have pairs of related sentences, then the best training method to use for sentence transformers is the supervised learning approach. This approach involves providing the model with labeled data, such as pairs of related sentences, and then training the model to learn the relationships between the sentences. This approach is often used for tasks such as text classification, sentiment analysis, and natural language understanding.'

# %%
embed_model = "text-embedding-ada-002"

res = openai.Embedding.create(
    input=[
        "Sample document text goes here",
        "there will be several phrases in each batch"
    ], engine=embed_model
)

# %%
# vector embeddings are stored within the 'data' key
res.keys()
# Out:
# dict_keys(['object', 'data', 'model', 'usage'])

# %%
# we have created two vectors (one for each sentence input)
len(res['data'])
# Out:
# 2

# %%
# we have created two 1536-dimensional vectors
len(res['data'][0]['embedding']), len(res['data'][1]['embedding'])
# Out:
# (1536, 1536)

# %% [markdown]
# # Alternative: Use pinecone to save the embeddings

# %%
#import pinecone

#index_name = 'openai-yannic-youtube-transcriptions-v2'

# initialize connection (get API key at app.pinecone.io)
#pinecone.init(
#    api_key="XXXX",
#    environment="us-east1-gcp"
#)

# %%
#pinecone.list_indexes()

# %%
# check if index already exists (it shouldn't if this is first time)
#if index_name not in pinecone.list_indexes():
    # if does not exist, create index
#    pinecone.create_index(
#        index_name,
#        dimension=len(res['data'][0]['embedding']),
#        metric='cosine'
#    )
# connect to index
#index = pinecone.Index(index_name)
# view index stats
#index.describe_index_stats()

# %%
mls_ds.set_format("pandas")
df = mls_ds[:]
df
# Out:
#                                                  TITLE  \
# 0    1.1 Machine Learning Overview | Welcome to mac...
# 1    1.2 Machine Learning Overview |  What is machi...
# 2    1.2 Machine Learning Overview |  What is machi...
# 3    1.3 Machine Learning Overview |  Applications ...
# 4    1.3 Machine Learning Overview |  Applications ...
# ..                                                 ...
# 405  10.15 Continuous State Spaces | Algorithm refi...
# 406  10.15 Continuous State Spaces | Algorithm refi...
# 407  10.15 Continuous State Spaces | Algorithm refi...
# 408  10.16 Continuous State Spaces |The state of re...
# 409  10.17 Conclusion | Summary and Thank you --[Ma...
#
#                                              URL  \
# 0    https://www.youtube.com/watch?v=y8JgiWcUnU8
# 1    https://www.youtube.com/watch?v=AISftYVyS50
# 2    https://www.youtube.com/watch?v=AISftYVyS50
# 3    https://www.youtube.com/watch?v=hHYcNPfbBXQ
# 4    https://www.youtube.com/watch?v=hHYcNPfbBXQ
# ..                                           ...
# 405  https://www.youtube.com/watch?v=3FkPgerAhXo
# 406  https://www.youtube.com/watch?v=3FkPgerAhXo
# 407  https://www.youtube.com/watch?v=3FkPgerAhXo
# 408  https://www.youtube.com/watch?v=pdeGAhJ5pbE
# 409  https://www.youtube.com/watch?v=GF1oHP5uDR8
#
#                                          TRANSCRIPTION  transcription_length  \
# 0    Welcome to machine learning. What is machine l...                   415
# 1    So, what is machine learning? In this video yo...                   500
# 2    to spend a lot of time on in this specializati...                   397
# 3    In this class, you learn about the state of th...                   500
# 4    by McKinsey, AI and machine learning is estima...                   201
# ..                                                 ...                   ...
# 405  so this inner term becomes 1 over 2 m prime su...                   500
# 406  is used more common than bash gradient descent...                   500
# 407  times W, in which case you're back to the orig...                   266
# 408  Reinforcement learning is an exciting set of t...                   464
# 409  Welcome to the final video of this machine lea...                   492
#
#                                                   text
# 0    1.1 Machine Learning Overview | Welcome to mac...
# 1    1.2 Machine Learning Overview |  What is machi...
# 2    1.2 Machine Learning Overview |  What is machi...
# 3    1.3 Machine Learning Overview |  Applications ...
# 4    1.3 Machine Learning Overview |  Applications ...
# ..                                                 ...
# 405  10.15 Continuous State Spaces | Algorithm refi...
# 406  10.15 Continuous State Spaces | Algorithm refi...
# 407  10.15 Continuous State Spaces | Algorithm refi...
# 408  10.16 Continuous State Spaces |The state of re...
# 409  10.17 Conclusion | Summary and Thank you --[Ma...
#
# [410 rows x 5 columns]

# %%
def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']

# %%
df['ada_embedding'] = df.text.apply(lambda x: get_embedding(x, model='text-embedding-ada-002'))

# %%
df.head()
df.to_csv('mls_ds.csv', index=False)

# %%
df = df.reset_index()

# %%
#from tqdm.auto import tqdm

#batch_size = 32

#for i in tqdm(range(0, len(df), batch_size)):
#    i_end = min(i+batch_size, len(df))
#    df_slice = df.iloc[i:i_end]
#    embeds = [row['ada_embedding'] for _, row in df_slice.iterrows()]
#    ids_batch = [str(n) for n in range(i, i_end)]
#    meta_data = [{
#        'title': row['TITLE'],
#        'url': row['URL'],
#        'text': row['text']
#    } for _, row in df_slice.iterrows()]
#    to_upsert = list(zip(ids_batch, embeds, meta_data))
#    index.upsert(vectors=to_upsert)

# %%
#query = "What thinks Francois Chollet about intelligence?"

#xq = openai.Embedding.create(input=query, engine=embed_model)['data'][0]['embedding']

# %%
#res = index.query([xq], top_k=5, include_metadata=True)
#res

# %%
#df_slice

# %%
#texts = [x["text"] for _, x in df_slice.iterrows()]

# %%
#texts

# %% [markdown]
# # Upload embedding to Hugging Face dataset
# Use pinecone for production apps.

# %%
from datasets import load_dataset

mls_ds = load_dataset("csv", data_files="/content/mls_ds.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-e8ef7e4ddba4> in <module>
#       1 from datasets import load_dataset
#       2
# ----> 3 mls_ds = load_dataset("csv", data_files="/content/mls_ds.csv")
#
# /usr/local/lib/python3.8/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1733
#    1734     # Create a dataset builder
# -> 1735     builder_instance = load_dataset_builder(
#    1736         path=path,
#    1737         name=name,
#
# /usr/local/lib/python3.8/dist-packages/datasets/load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, **config_kwargs)
#    1491         download_config = download_config.copy() if download_config else DownloadConfig()
#    1492         download_config.use_auth_token = use_auth_token
# -> 1493     dataset_module = dataset_module_factory(
#    1494         path,
#    1495         revision=revision,
#
# /usr/local/lib/python3.8/dist-packages/datasets/load.py in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1127     # Try packaged
#    1128     if path in _PACKAGED_DATASETS_MODULES:
# -> 1129         return PackagedDatasetModuleFactory(
#    1130             path,
#    1131             data_dir=data_dir,
#
# /usr/local/lib/python3.8/dist-packages/datasets/load.py in get_module(self)
#     706             sanitize_patterns(self.data_files) if self.data_files is not None else get_data_patterns_locally(base_path)
#     707         )
# --> 708         data_files = DataFilesDict.from_local_or_remote(
#     709             patterns,
#     710             use_auth_token=self.download_config.use_auth_token,
#
# /usr/local/lib/python3.8/dist-packages/datasets/data_files.py in from_local_or_remote(cls, patterns, base_path, allowed_extensions, use_auth_token)
#     794         for key, patterns_for_key in patterns.items():
#     795             out[key] = (
# --> 796                 DataFilesList.from_local_or_remote(
#     797                     patterns_for_key,
#     798                     base_path=base_path,
#
# /usr/local/lib/python3.8/dist-packages/datasets/data_files.py in from_local_or_remote(cls, patterns, base_path, allowed_extensions, use_auth_token)
#     762     ) -> "DataFilesList":
#     763         base_path = base_path if base_path is not None else str(Path().resolve())
# --> 764         data_files = resolve_patterns_locally_or_by_urls(base_path, patterns, allowed_extensions)
#     765         origin_metadata = _get_origin_metadata_locally_or_by_urls(data_files, use_auth_token=use_auth_token)
#     766         return cls(data_files, origin_metadata)
#
# /usr/local/lib/python3.8/dist-packages/datasets/data_files.py in resolve_patterns_locally_or_by_urls(base_path, patterns, allowed_extensions)
#     360             data_files.append(Url(pattern))
#     361         else:
# --> 362             for path in _resolve_single_pattern_locally(base_path, pattern, allowed_extensions):
#     363                 data_files.append(path)
#     364
#
# /usr/local/lib/python3.8/dist-packages/datasets/data_files.py in _resolve_single_pattern_locally(base_path, pattern, allowed_extensions)
#     304         if allowed_extensions is not None:
#     305             error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 306         raise FileNotFoundError(error_msg)
#     307     return sorted(out)
#     308
#
# FileNotFoundError: Unable to find '/content/mls_ds.csv' at /

# %%
mls_ds["train"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-1d622e7173be> in <module>
# ----> 1 mls_ds["train"][0]
#
# /usr/local/lib/python3.8/dist-packages/datasets/arrow_dataset.py in __getitem__(self, key)
#    2588     def __getitem__(self, key):  # noqa: F811
#    2589         """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2590         return self._getitem(
#    2591             key,
#    2592         )
#
# /usr/local/lib/python3.8/dist-packages/datasets/arrow_dataset.py in _getitem(self, key, **kwargs)
#    2572         format_kwargs = format_kwargs if format_kwargs is not None else {}
#    2573         formatter = get_formatter(format_type, features=self.features, **format_kwargs)
# -> 2574         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
#    2575         formatted_output = format_table(
#    2576             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#
# /usr/local/lib/python3.8/dist-packages/datasets/formatting/formatting.py in query_table(table, key, indices)
#     583         _raise_bad_key_type(key)
#     584     if isinstance(key, str):
# --> 585         _check_valid_column_key(key, table.column_names)
#     586     else:
#     587         size = indices.num_rows if indices is not None else table.num_rows
#
# /usr/local/lib/python3.8/dist-packages/datasets/formatting/formatting.py in _check_valid_column_key(key, columns)
#     523 def _check_valid_column_key(key: str, columns: List[str]) -> None:
#     524     if key not in columns:
# --> 525         raise KeyError(f"Column {key} not in the dataset. Current columns in the dataset: {columns}")
#     526
#     527
#
# KeyError: "Column train not in the dataset. Current columns in the dataset: ['TITLE', 'URL', 'TRANSCRIPTION', 'transcription_length', 'text']"

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
mls_ds.push_to_hub("juancopi81/mls_ada_embeddings")
# Out:
# WARNING:datasets.dataset_dict:Pushing split train to the Hub.
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
